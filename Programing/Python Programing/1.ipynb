# %%
print('Hello World')
# Out:
# Hello World

# %%
print('Hello World','Here python is working fine')
# Out:
# Hello World Here python is working fine

# %%
print(23)
print(35+10)
# Out:
# 23
# 45

# %%
name = "Prince"
age = 21
hight = 5.89

print(name) 
print(age) 
print(hight) 

print("my name is ",name)
print("my age is ", age)
# Out:
# Prince
# 21
# 5.89
# my name is  Prince
# my age is  21
