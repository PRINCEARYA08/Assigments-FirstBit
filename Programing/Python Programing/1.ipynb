# %%
print('Hello World')
# Out:
# Hello World

# %%
print('Hello World','Here python is working fine')
# Out:
# Hello World Here python is working fine

# %%
print(23)
print(35+10)
# Out:
# 23
# 45

# %%
name = "Prince"
age = 21
hight = 5.89

print(name) 
print(age) 
print(hight) 

print("my name is ",name)
print("my age is ", age)
# Out:
# Prince
# 21
# 5.89
# my name is  Prince
# my age is  21

# %%
# python follow assigment rule

age = 21
print(age)
age2 = 22
print(age2)
# Out:
# 21
# 22

# %%
number = 12334
name  = "Prince"
marks = 89.80
status = True
next = None

print(type(number))
print(type(name))
print(type(marks))
print(type(status))
print(type(next))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
# Python Case sensentive language
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Sum 
a = 7
b = 4

sum = a + b

print ("Sum of a and b is ",sum)
# Out:
# Sum of a and b is  3

# %%
#Types of Oprators in Python
a = 5
b = 7

print(a + b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)#remainder
print(a**b)#a^b


#relational oprators
c=50
d=20

print(c == d)#False
print(c!=d)#True
print(c >= d)#True
print(c > d)#True
print(c <= d)#False
print(c < d)#False
# Out:
# 12
# -2
# 35
# 0.7142857142857143
# 5
# 78125
# False
# True
# True
# True
# False
# False

# %%
#assigment oprators
num = 10

num =  num + 10
# num+=10
# num*=10
# num%=10
# num**=10
print(num)
# Out:
# 20

# %%
# Logical oprators
# not
print(not False)
print(not True)

a = 30
b = 20
print(not(a>b))
print(a>b)


 
# and    
val1 = True
val2 = False
print("AND Operator :", val1 and val2)
# work only if both conditions are true

# or
print("OR Operator :", val1 or val2)
# work if any one condition is true
# Out:
# True
# False
# False
# True
# AND Operator : False
# OR Operator : True

# %%
# Type conversion

#1 conversion (automaticaly)

a = 2
b = 4.25

sum = a + b # 2.0 + 4.25 => 6.25
print(sum)
# Out:
# 6.25

# %%
#2 Casting (Manucaly)
a =int("2")
b = 4.25
print(a+b)


#--------------------------------

c = 3.14
print(type(c))

c = str(c)

print(type(c))

# here we casting float value to sting value
# Out:
# 6.25
# <class 'float'>
# <class 'str'>
