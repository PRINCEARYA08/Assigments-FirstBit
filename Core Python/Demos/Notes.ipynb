# %% [markdown]
# # Notes

# %% [markdown]
# ### 1. Literals

# %%
'First code '
10
[10,20,30]

# %% [markdown]
# ### 2. Identifier : Unique names of variable, function, Class

# %%
City = 'Bhopal'
num = 10

# %% [markdown]
# ### 3. Variable

# %% [markdown]
# #### 1. Identifier for values
# #### 2. has ability to idenstify diffresnt value
# #### 3. placeholder for memoery location
#
# ----------------------------------------------
#
# #### rules to define variable name
# #### 1. can contain alpha, digits, underscore
# #### 2. can't contain space

# %%
num_1 = 10
#nu m = 10 #will raise error

# %% [markdown]
# ### Keywords
# #### 1. Pre-define words: specific meaning
# #### 2. Reserved Word

# %%
import keyword
print(keyword.kwlist)  #print all keywords in python
print(len(keyword.kwlist))  #print total number of keywords in python
