# %% [markdown]
# ### Basic Syntax

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Variable

# %%
Sugar = "chini"

print(Sugar)
print("chini", Sugar)
# Out:
# chini
# chini chini

# %% [markdown]
# ## Comments

# %%
# This is a comment
    # efue
    # efef

# %% [markdown]
# ## Indentation

# %%
age = 19
if(age > 18):
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %% [markdown]
# ## Keywords

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## Identifier

# %%
_123keyword = "This is a variable"
print(_123keyword)
# Out:
# This is a variable

# %% [markdown]
# ## Basic I/O

# %%
tree = "Chandan"
print("tree Name is : ", tree)


name = input("Enter your name : ")
print("Hello", name)
# Out:
# tree Name is :  Chandan
# Hello prince

# %% [markdown]
# # Data Types

# %% [markdown]
# #### Numbers

# %%
#int
a = 10

#float
b = 10.5

#complex
c = 2 + 3j

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# ### Boolean

# %%
# true and false are boolean values
is_true = True

print(type(is_true))
print(4<6)
# Out:
# <class 'bool'>
# True

# %% [markdown]
# ## String

# %%
a = "Hammer"
print(type(a))

print(a[4])
print(a[1:4])
print(a[1:4:2])
print(a[1:])
print(a[:4])
print(a.upper())
print(a.lower())
print(a.replace("Hammer", "Screwdriver"))

#a = a.replace("Hammer", "Screwdriver")
print(a)
# Out:
# <class 'str'>
# e
# amm
# am
# ammer
# Hamm
# HAMMER
# hammer
# Screwdriver
# Hammer

# %% [markdown]
# ## NoneType

# %%
a =None
#a ="Hammer"
#a ="Hammer"
print(type(a))
# Out:
# <class 'NoneType'>
